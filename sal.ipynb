# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"C:\Users\dines\OneDrive\Desktop\Machine learning\Salary_dataset.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head(5)
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
X=df[['YearsExperience']]
y=df['Salary']

Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,y,test_size=0.4,random_state=40)

model = LinearRegression()
model.fit(Xtrain,Ytrain)
model.score(Xtest,Ytest)
#
# Out:
# 0.9089365888474455

# %%
ypred=model.predict(Xtest)

# %%
model.coef_
# Out:
# array([8989.49459436])

# %%
model.intercept_
# Out:
# np.float64(29097.878004338418)

# %% [markdown]
# model evaluation #imp (2)

# %%
from sklearn.metrics import mean_squared_error
ypred
mean_squared_error(Ytest,ypred)
# Out:
# 58053645.7782171

# %% [markdown]
# the mean_error is high but the score is good that means that model need to b trained with more data and can use diff algorithm

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(Ytest,ypred)
# Out:
# 6904.617718004341

# %%
from sklearn.preprocessing import PolynomialFeatures

#step 1 creating polynomial features model
poly=PolynomialFeatures(degree=2)

#step 2 transform x -->xpoly

xpoly=poly.fit_transform(Xtrain)
# xpoly
model=LinearRegression()
model.fit(xpoly,Ytrain)
# Out:
# LinearRegression()

# %%
xtest_poly=poly.transform(Xtest)
ypred=model.predict(xtest_poly)
ypred
# Out:
# array([ 43966.37282427,  75428.80431599,  83494.00416924,  70096.35818722,
#         73647.37971543,  66561.10688956,  90730.09418528,  48259.7679217 ,
#        125017.55531747,  93459.89099155,  65679.75816367,  49984.02543653])

# %%
plt.scatter(Xtrain,Ytrain)
plt.scatter(Xtest,ypred)
